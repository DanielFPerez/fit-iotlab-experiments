# %%
import json
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
# Path to the local file
file_path = './lille-nodes_coord.json'

# Reading the JSON data from the local file
with open(file_path, 'r') as file:
    data = json.load(file)

# Extract node coordinates
x_vals = [node["x"] for node in data["nodes"].values()]
y_vals = [node["y"] for node in data["nodes"].values()]
z_vals = [node["z"] for node in data["nodes"].values()]

# %%
# Plotting the nodes in 3D space
in_size = (14, 8)

fig = plt.figure(figsize=in_size)
ax = fig.add_subplot(111, projection='3d')

ax.scatter(x_vals, y_vals, z_vals, c='r', marker='o')

# Adding labels and titles
ax.set_xlabel('X Coordinate')
ax.set_ylabel('Y Coordinate')
ax.set_zlabel('Z Coordinate')
ax.set_title('3D Visualization of Nodes')

# Display the plot
plt.show()

# %%
import plotly.graph_objs as go
import plotly.io as pio

pio.renderers.default = 'iframe'

# Create the 3D scatter plot using Plotly
trace = go.Scatter3d(
    x=x_vals,
    y=y_vals,
    z=z_vals,
    mode='markers',
    marker=dict(
        size=8,
        color='red',
        opacity=0.8
    )
)

# Set up the layout
layout = go.Layout(
    scene=dict(
        xaxis_title='X Coordinate',
        yaxis_title='Y Coordinate',
        zaxis_title='Z Coordinate'
    ),
    title='Interactive 3D Visualization of Nodes', 
    width=1000,   # Increase the width
    height=800    # Increase the height
)

# Create the figure
fig = go.Figure(data=[trace], layout=layout)

# Display the plot
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_6.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>
